# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %%bash
# wget -q https://github.com/wkhtmltopdf/packaging/releases/download/0.12.6-1/wkhtmltox_0.12.6-1.bionic_amd64.deb
# cp wkhtmltox_0.12.6-1.bionic_amd64.deb /usr/bin
# apt -qq install /usr/bin/wkhtmltox_0.12.6-1.bionic_amd64.deb > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !pip install -qqq transformers==4.27.2 --progress-bar off
# !pip install -qqq pytorch-lightning==1.9.4 --progress-bar off
# !pip install -qqq torchmetrics==0.11.4 --progress-bar off
# !pip install -qqq imgkit==1.2.3 --progress-bar off
# !pip install -qqq easyocr==1.6.2 --progress-bar off
# !pip install -qqq Pillow==9.4.0 --progress-bar off
# !pip install -qqq tensorboardX==2.5.1 --progress-bar off
# !pip install -qqq huggingface_hub==0.11.1 --progress-bar off
# !pip install -qqq --upgrade --no-cache-dir gdown

# %%
# !pip install -qqq pytorch-lightning==1.9.4 --progress-bar off

# %%
from transformers import LayoutLMv3FeatureExtractor, LayoutLMv3TokenizerFast, LayoutLMv3Processor, LayoutLMv3ForSequenceClassification
from tqdm import tqdm
import torch
from torch.utils.data import Dataset, DataLoader
# import pytorch_lightning as pl
# from pytorch_lightning.callbacks import ModelCheckpoint
from PIL import Image, ImageDraw, ImageFont
import numpy as np
from sklearn.model_selection import train_test_split
import imgkit
import easyocr
import torchvision.transforms as T
from pathlib import Path
import matplotlib.pyplot as plt
import os
import cv2
from typing import List
import json
from torchmetrics import Accuracy
# from huggingface_hub import notebook_login
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %matplotlib inline
# pl.seed_everything(42)

# %%
# !gdown 1tMZXonmajLPK9zhZ2dt-CdzRTs5YfHy0
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tMZXonmajLPK9zhZ2dt-CdzRTs5YfHy0
# To: G:\programming\Packagex_assignment\LayoutLMv3\financial-documents.zip
#
#   0%|          | 0.00/3.10M [00:00<?, ?B/s]
#  17%|#6        | 524k/3.10M [00:01<00:07, 356kB/s]
#  34%|###3      | 1.05M/3.10M [00:02<00:05, 374kB/s]
#  51%|#####     | 1.57M/3.10M [00:04<00:04, 380kB/s]
#  68%|######7   | 2.10M/3.10M [00:05<00:02, 401kB/s]
#  85%|########4 | 2.62M/3.10M [00:10<00:02, 188kB/s]
# 100%|##########| 3.10M/3.10M [00:13<00:00, 192kB/s]
# 100%|##########| 3.10M/3.10M [00:13<00:00, 236kB/s]

# %%
# !unzip -q financial-documents.zip
# !mv "TableClassifierQuaterlyWithNotes" "documents"
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !move "TableClassifierQuaterlyWithNotes" "documents"
# Out:
#         1 dir(s) moved.

# %% [markdown]
# ## Convert HTML to images

# %%
from pathlib import Path
for dir in Path("documents").glob("*"):
    dir.rename(str(dir).lower().replace(" ", "_"))

# %%
list(Path("documents").glob("*"))
# Out:
# [WindowsPath('documents/balance_sheets'),
#  WindowsPath('documents/cash_flow'),
#  WindowsPath('documents/income_statement'),
#  WindowsPath('documents/notes'),
#  WindowsPath('documents/others')]

# %%
for dir in Path("documents").glob("*"):
    image_dir = Path(f"images/{dir.name}")
    image_dir.mkdir(exist_ok=True, parents=True)

# %%
def convert_html_to_image(file_path: Path, images_dir: Path, scale: float = 1.0) -> Path:
    file_name = file_path.with_suffix(".jpg").name
    save_path = images_dir / file_path.parent.name / f"{file_name}"
    imgkit.from_file(str(file_path), save_path, options={'quiet': '', 'format': 'jpeg'})

    image = Image.open(save_path)
    width, height = image.size
    image = image.resize((int(width * scale), int(height * scale)))
    image.save(str(save_path))

    return save_path

# %%
from tqdm import tqdm
import imgkit
document_paths = list(Path("documents").glob("*/*"))

for doc_path in tqdm(document_paths):
    convert_html_to_image(doc_path, Path("images"), scale=0.8)
# Out:
#   0%|                                                                                         | 0/2573 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 6
#       3 document_paths = list(Path("documents").glob("*/*"))
#       5 for doc_path in tqdm(document_paths):
# ----> 6     convert_html_to_image(doc_path, Path("images"), scale=0.8)
#
# Cell In[11], line 4, in convert_html_to_image(file_path, images_dir, scale)
#       2 file_name = file_path.with_suffix(".jpg").name
#       3 save_path = images_dir / file_path.parent.name / f"{file_name}"
# ----> 4 imgkit.from_file(str(file_path), save_path, options={'quiet': '', 'format': 'jpeg'})
#       6 image = Image.open(save_path)
#       7 width, height = image.size
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\imgkit\api.py:62, in from_file(filename, output_path, options, toc, cover, css, config, cover_first)
#      39 def from_file(
#      40     filename,
#      41     output_path,
#    (...)
#      47     cover_first=None,
#      48 ):
#      49     """
#      50     Convert HTML file/files to IMG file/files
#      51
#    (...)
#      60     :return: True when success
#      61     """
# ---> 62     rtn = IMGKit(
#      63         filename,
#      64         "file",
#      65         options=options,
#      66         toc=toc,
#      67         cover=cover,
#      68         css=css,
#      69         config=config,
#      70         cover_first=cover_first,
#      71     )
#      72     return rtn.to_img(output_path)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\imgkit\imgkit.py:36, in IMGKit.__init__(self, url_or_file, source_type, options, config, **kwargs)
#      34 self.source = Source(url_or_file, source_type)
#      35 self.config = Config() if not config else config
# ---> 36 self.wkhtmltoimage = self.config.get_wkhtmltoimage()
#      38 self.options = {}
#      39 if self.source.isString():
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\imgkit\config.py:57, in Config.get_wkhtmltoimage(self)
#      55         raise_from(OSError(wkhtmltoimage_error), io_error)
#      56 else:
# ---> 57     raise OSError(wkhtmltoimage_error)
#      59 return self.wkhtmltoimage
#
# OSError:
# No wkhtmltoimage executable found: "command not found"
# If this file exists please check that this process can read it.
# Otherwise please install wkhtmltopdf - http://wkhtmltopdf.org

# %%
from PIL import Image, ImageDraw, ImageFont
image_paths = sorted(list(Path("images").glob("*/*.png")))

image = Image.open(image_paths[0]).convert("RGB")
width, height = image.size
image
# Out:
# <PIL.Image.Image image mode=RGB size=754x1000>

# %% [markdown]
# ## EasyOCR

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
# %%time
image_path = image_paths[0]
ocr_result = reader.readtext(str(image_path))
# Out:
# CPU times: total: 26.3 s
# Wall time: 6.83 s

# %%
ocr_result[0]
# Out:
# ([[111, 89], [157, 89], [157, 103], [111, 103]], 'From:', 0.9658447727958701)

# %%
import os
import urllib.request

font_path = Path(cv2.__path__[0]) / "qt/fonts/DejaVuSansCondensed.ttf"

if not font_path.exists():
    # Font file not found, download and save the font file
    os.makedirs(font_path.parent, exist_ok=True)
    url = "https://github.com/mps/fonts/blob/master/DejaVuSansCondensed.ttf"  # Replace with the URL to the font file
    urllib.request.urlretrieve(url, font_path)

# %%
print(Path(cv2.__path__[0]) / "qt/fonts/DejaVuSansCondensed.ttf")
# Out:
# C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\cv2\qt\fonts\DejaVuSansCondensed.ttf

# %%
font_path = Path(cv2.__path__[0]) / "qt/fonts/DejaVuSansCondensed.ttf"
print(font_path.exists())
# font = ImageFont.truetype(str(font_path), size=12)
font = ImageFont.load_default()
# Out:
# True

# %%
def create_bounding_box(bbox_data):
    xs = []
    ys = []
    for x, y in bbox_data:
        xs.append(x)
        ys.append(y)
    
    left = int(min(xs))
    top = int(min(ys))
    right = int(max(xs))
    bottom = int(max(ys))

    return [left, top, right, bottom]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(28, 28))

left_image = Image.open(image_path).convert("RGB")
right_image = Image.new("RGB", left_image.size, (255, 255, 255))

left_draw = ImageDraw.Draw(left_image)
right_draw = ImageDraw.Draw(right_image)

for i, (bbox, word, confidence) in enumerate(ocr_result):
    box = create_bounding_box(bbox)

    left_draw.rectangle(box, outline="blue", width=2)
    left, top, right, bottom = box

    left_draw.text((right + 5, top), text=str(i + 1), fill="red", font=font) 
    right_draw.text((left, top), text=word, fill="black", font=font)
    
ax1.imshow(left_image)
ax2.imshow(right_image)
ax1.axis("off");
ax2.axis("off");

# %%
for image_path in tqdm(image_paths):
    ocr_result = reader.readtext(str(image_path), batch_size=16)

    ocr_page = []
    for bbox, word, confidence in ocr_result:
        ocr_page.append({
            "word": word, "bounding_box": create_bounding_box(bbox)
        })
    
    with image_path.with_suffix(".json").open("w") as f:
        json.dump(ocr_page, f)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 165/165 [48:20<00:00, 17.58s/it]

# %%
# !tar -cJf financial-documents-ocr.tar.xz "./images"
# Out:
# tar: Unsupported compression option --xz

# %%
# !tar -czf financial-documents-ocr.tar.gz "./images"

# %%
# !gdown 1bQ4mFbVRUtOEJSe8b4hUYIcngSgfdldw
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bQ4mFbVRUtOEJSe8b4hUYIcngSgfdldw
# To: /content/financial-documents-ocr.tar.xz
# 100% 147M/147M [00:02<00:00, 52.7MB/s]

# %%
# !tar -xf financial-documents-ocr.tar.xz

# %%
image_paths = sorted(list(Path("images").glob("*/*.png")))

# %% [markdown]
# ## LayoutLMv3

# %% [markdown]
# ### Preprocessing

# %%
feature_extractor = LayoutLMv3FeatureExtractor(apply_ocr=False)
tokenizer = LayoutLMv3TokenizerFast.from_pretrained("microsoft/layoutlmv3-base")
processor = LayoutLMv3Processor(feature_extractor, tokenizer)
# Out:
# C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\transformers\models\layoutlmv3\feature_extraction_layoutlmv3.py:30: FutureWarning: The class LayoutLMv3FeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use LayoutLMv3ImageProcessor instead.
#   warnings.warn(

# %% [markdown]
# Calling the processor is similar to a using a tokenizer:

# %%
image_path = image_paths[0]
image = Image.open(image_path).convert("RGB")
width, height = image.size
width, height
# Out:
# (754, 1000)

# %%
width_scale = 1000 / width
height_scale = 1000 / height

width_scale, height_scale
# Out:
# (1.3262599469496021, 1.0)

# %%
json_path = image_path.with_suffix(".json")
json_path
# Out:
# WindowsPath('images/email/doc_000042.json')

# %%
with json_path.open("r") as f:
    ocr_result = json.load(f)

# %%
def scale_bounding_box(box: List[int], width_scale : float = 1.0, height_scale : float = 1.0) -> List[int]:
    return [
        int(box[0] * width_scale),
        int(box[1] * height_scale),
        int(box[2] * width_scale),
        int(box[3] * height_scale)
    ]

# %%
words = []
boxes = []
for row in ocr_result:
    boxes.append(scale_bounding_box(row["bounding_box"], width_scale, height_scale))
    words.append(row["word"])

# %%
len(words), len(boxes)
# Out:
# (44, 44)

# %%
encoding = processor(
    image, 
    words,
    boxes=boxes,
    max_length=512,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
)

encoding.keys()
# Out:
# dict_keys(['input_ids', 'attention_mask', 'bbox', 'pixel_values'])

# %%
print(f"""
input_ids:  {list(encoding["input_ids"].squeeze().shape)}
word boxes: {list(encoding["bbox"].squeeze().shape)}
image data: {list(encoding["pixel_values"].squeeze().shape)} 
image size: {image.size}
""")
# Out:
# input_ids:  [512]
# word boxes: [512, 4]
# image data: [3, 224, 224]
# image size: (754, 1000)

# %% [markdown]
# ##### Image

# %%
image_data = encoding["pixel_values"][0]
image_data.shape
# Out:
# torch.Size([3, 224, 224])

# %%
transform = T.ToPILImage()
transform(image_data)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Word boxes use the `[left, top, right, bottom]` format.

# %%
def unnormalize_box(bbox, width, height):
    return [
        width * (bbox[0] / 1000),
        height * (bbox[1] / 1000),
        width * (bbox[2] / 1000),
        height * (bbox[3] / 1000),
    ]

# %% [markdown]
# ### Model

# %%
model = LayoutLMv3ForSequenceClassification.from_pretrained("microsoft/layoutlmv3-base", num_labels=3)
# Out:
# Some weights of LayoutLMv3ForSequenceClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.config
# Out:
# LayoutLMv3Config {
#   "_name_or_path": "microsoft/layoutlmv3-base",
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "coordinate_size": 128,
#   "eos_token_id": 2,
#   "has_relative_attention_bias": true,
#   "has_spatial_attention_bias": true,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "input_size": 224,
#   "intermediate_size": 3072,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "layer_norm_eps": 1e-05,
#   "max_2d_position_embeddings": 1024,
#   "max_position_embeddings": 514,
#   "max_rel_2d_pos": 256,
#   "max_rel_pos": 128,
#   "model_type": "layoutlmv3",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "patch_size": 16,
#   "rel_2d_pos_bins": 64,
#   "rel_pos_bins": 32,
#   "second_input_size": 112,
#   "shape_size": 128,
#   "text_embed": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.29.0.dev0",
#   "type_vocab_size": 1,
#   "visual_embed": true,
#   "vocab_size": 50265
# }

# %%
encoding = processor(
    image, 
    words,
    boxes=boxes,
    max_length=512,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
)

outputs = model(**encoding)
# Out:
# C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\transformers\modeling_utils.py:862: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(

# %%
outputs.logits
# Out:
# tensor([[-0.1715, -0.2032, -0.0144]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Training

# %%
train_images, test_images = train_test_split(image_paths, test_size=.2)

# %%
DOCUMENT_CLASSES = sorted(list(map(lambda p: p.name, Path("images").glob("*"))))
DOCUMENT_CLASSES
# Out:
# ['email', 'resume', 'scientific_publication']

# %%
image_path = image_paths[100]
print(image_path)
DOCUMENT_CLASSES.index(image_path.parent.name)
# Out:
# images\resume\doc_000674.png
# 1

# %%
image_path = image_paths[0]
print(image_path)
DOCUMENT_CLASSES.index(image_path.parent.name)
# Out:
# images\email\doc_000042.png
# 0

# %%
class DocumentClassificationDataset(Dataset):

    def __init__(self, image_paths, processor):
        self.image_paths = image_paths
        self.processor = processor
  
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, item):

        image_path = self.image_paths[item]
        json_path = image_path.with_suffix(".json")
        with json_path.open("r") as f:
            ocr_result = json.load(f)
        
            with Image.open(image_path).convert("RGB") as image:
    
                width, height = image.size
                width_scale = 1000 / width
                height_scale = 1000 / height
        
                words = []
                boxes = []
                for row in ocr_result:
                    boxes.append(scale_bounding_box(row["bounding_box"], width_scale, height_scale))
                    words.append(row["word"])
        
                encoding = self.processor(
                    image, 
                    words,
                    boxes=boxes,
                    max_length=512,
                    padding="max_length",
                    truncation=True,
                    return_tensors="pt"
                )
        
        label = DOCUMENT_CLASSES.index(image_path.parent.name)

        return dict(
            input_ids=encoding["input_ids"].flatten(),
            attention_mask=encoding["attention_mask"].flatten(),
            bbox=encoding["bbox"].flatten(end_dim=1),
            pixel_values=encoding["pixel_values"].flatten(end_dim=1),
            labels=torch.tensor(label, dtype=torch.long)
        )

# %%
train_dataset = DocumentClassificationDataset(train_images, processor)
test_dataset = DocumentClassificationDataset(test_images, processor)

# %%
for item in train_dataset:
    print(item["bbox"].shape)
    print(item["pixel_values"].shape)
    print(item["labels"].shape)
    break
# Out:
# torch.Size([512, 4])
# torch.Size([3, 224, 224])
# torch.Size([])

# %%
train_data_loader = DataLoader(
    train_dataset,
    batch_size=8,
    shuffle=True,
    num_workers=2
)

test_data_loader = DataLoader(
    test_dataset,
    batch_size=8,
    shuffle=False,
    num_workers=2
)

# %%
from torch import nn

class ModelModule(nn.Module):
    def __init__(self, n_classes:int):
        super().__init__()
        self.model = LayoutLMv3ForSequenceClassification.from_pretrained(
            "microsoft/layoutlmv3-base", 
            num_labels=n_classes
        )
        self.model.config.id2label = {k: v for k, v in enumerate(DOCUMENT_CLASSES)}
        self.model.config.label2id = {v: k for k, v in enumerate(DOCUMENT_CLASSES)}
        self.train_accuracy = Accuracy(task="multiclass", num_classes=n_classes)
        self.val_accuracy = Accuracy(task="multiclass", num_classes=n_classes)

    def forward(self, input_ids, attention_mask, bbox, pixel_values, labels=None):
        return self.model(
            input_ids, 
            attention_mask=attention_mask,
            bbox=bbox,
            pixel_values=pixel_values,
            labels=labels
        )

    def training_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        bbox = batch["bbox"]
        pixel_values = batch["pixel_values"]
        labels = batch["labels"]
        output = self(input_ids, attention_mask, bbox, pixel_values, labels)
        self.log("train_loss", output.loss)
        self.log("train_acc", self.train_accuracy(output.logits, labels), on_step=True, on_epoch=True)
        return output.loss

    def validation_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        bbox = batch["bbox"]
        pixel_values = batch["pixel_values"]
        labels = batch["labels"]
        output = self(input_ids, attention_mask, bbox, pixel_values, labels)
        self.log("val_loss", output.loss)
        self.log("val_acc", self.val_accuracy(output.logits, labels), on_step=False, on_epoch=True)
        return output.loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.model.parameters(), lr=0.00001) #1e-5
        return optimizer

# %%
model_module = ModelModule(len(DOCUMENT_CLASSES))
# Out:
# Some weights of LayoutLMv3ForSequenceClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
len(DOCUMENT_CLASSES)
# Out:
# 3

# %%
# !pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.12.2-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.6 MB 330.3 kB/s eta 0:00:17
#      ---------------------------------------- 0.0/5.6 MB 281.8 kB/s eta 0:00:20
#      ---------------------------------------- 0.0/5.6 MB 281.8 kB/s eta 0:00:20
#      ---------------------------------------- 0.1/5.6 MB 252.2 kB/s eta 0:00:23
#      ---------------------------------------- 0.1/5.6 MB 252.2 kB/s eta 0:00:23
#       --------------------------------------- 0.1/5.6 MB 270.5 kB/s eta 0:00:21
#       --------------------------------------- 0.1/5.6 MB 262.6 kB/s eta 0:00:22
#       --------------------------------------- 0.1/5.6 MB 288.8 kB/s eta 0:00:20
#      - -------------------------------------- 0.1/5.6 MB 315.4 kB/s eta 0:00:18
#      - -------------------------------------- 0.2/5.6 MB 327.5 kB/s eta 0:00:17
#      - -------------------------------------- 0.2/5.6 MB 308.5 kB/s eta 0:00:18
#      - -------------------------------------- 0.2/5.6 MB 318.9 kB/s eta 0:00:18
#      - -------------------------------------- 0.2/5.6 MB 318.9 kB/s eta 0:00:18
#      - -------------------------------------- 0.2/5.6 MB 320.0 kB/s eta 0:00:17
#      - -------------------------------------- 0.2/5.6 MB 327.6 kB/s eta 0:00:17
#      - -------------------------------------- 0.3/5.6 MB 321.3 kB/s eta 0:00:17
#      - -------------------------------------- 0.3/5.6 MB 321.3 kB/s eta 0:00:17
#      - -------------------------------------- 0.3/5.6 MB 309.9 kB/s eta 0:00:18
#      -- ------------------------------------- 0.3/5.6 MB 305.2 kB/s eta 0:00:18
#      -- ------------------------------------- 0.3/5.6 MB 311.6 kB/s eta 0:00:18
#      -- ------------------------------------- 0.3/5.6 MB 322.6 kB/s eta 0:00:17
#      -- ------------------------------------- 0.3/5.6 MB 317.8 kB/s eta 0:00:17
#      -- ------------------------------------- 0.4/5.6 MB 327.8 kB/s eta 0:00:17
#      -- ------------------------------------- 0.4/5.6 MB 323.2 kB/s eta 0:00:17
#      -- ------------------------------------- 0.4/5.6 MB 323.3 kB/s eta 0:00:17
#      -- ------------------------------------- 0.4/5.6 MB 323.6 kB/s eta 0:00:17
#      -- ------------------------------------- 0.4/5.6 MB 319.8 kB/s eta 0:00:17
#      --- ------------------------------------ 0.4/5.6 MB 323.9 kB/s eta 0:00:17
#      --- ------------------------------------ 0.5/5.6 MB 320.2 kB/s eta 0:00:17
#      --- ------------------------------------ 0.5/5.6 MB 320.2 kB/s eta 0:00:17
#      --- ------------------------------------ 0.5/5.6 MB 317.1 kB/s eta 0:00:17
#      --- ------------------------------------ 0.5/5.6 MB 320.9 kB/s eta 0:00:17
#      --- ------------------------------------ 0.5/5.6 MB 317.7 kB/s eta 0:00:17
#      --- ------------------------------------ 0.5/5.6 MB 321.2 kB/s eta 0:00:16
#      --- ------------------------------------ 0.5/5.6 MB 318.4 kB/s eta 0:00:17
#      --- ------------------------------------ 0.6/5.6 MB 318.7 kB/s eta 0:00:16
#      --- ------------------------------------ 0.6/5.6 MB 318.7 kB/s eta 0:00:16
#      ---- ----------------------------------- 0
kB/s eta 0:00:02
#      ----------------------------------- ---- 3.4/3.8 MB 341.2 kB/s eta 0:00:02
#      ----------------------------------- ---- 3.4/3.8 MB 342.2 kB/s eta 0:00:02
#      ------------------------------------ --- 3.4/3.8 MB 343.1 kB/s eta 0:00:02
#      ------------------------------------ --- 3.4/3.8 MB 344.1 kB/s eta 0:00:01
#      ------------------------------------ --- 3.5/3.8 MB 343.5 kB/s eta 0:00:01
#      ------------------------------------ --- 3.5/3.8 MB 344.5 kB/s eta 0:00:01
#      ------------------------------------- -- 3.5/3.8 MB 344.9 kB/s eta 0:00:01
#      ------------------------------------- -- 3.5/3.8 MB 345.8 kB/s eta 0:00:01
#      ------------------------------------- -- 3.5/3.8 MB 345.2 kB/s eta 0:00:01
#      ------------------------------------- -- 3.6/3.8 MB 346.2 kB/s eta 0:00:01
#      ------------------------------------- -- 3.6/3.8 MB 345.6 kB/s eta 0:00:01
#      -------------------------------------- - 3.6/3.8 MB 346.9 kB/s eta 0:00:01
#      -------------------------------------- - 3.6/3.8 MB 346.9 kB/s eta 0:00:01
#      -------------------------------------- - 3.6/3.8 MB 348.3 kB/s eta 0:00:01
#      -------------------------------------- - 3.7/3.8 MB 348.7 kB/s eta 0:00:01
#      ---------------------------------------  3.7/3.8 MB 350.0 kB/s eta 0:00:01
#      ---------------------------------------  3.7/3.8 MB 350.9 kB/s eta 0:00:01
#      ---------------------------------------  3.7/3.8 MB 350.8 kB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 351.6 kB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 351.6 kB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 351.6 kB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 351.6 kB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 351.6 kB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 351.6 kB/s eta 0:00:01
#      ---------------------------------------  3.8/3.8 MB 351.6 kB/s eta 0:00:01
#      ---------------------------------------- 3.8/3.8 MB 342.4 kB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.1)
# Installing collected packages: werkzeug, markdown, grpcio, absl-py, tensorboard
# Successfully installed absl-py-1.4.0 grpcio-1.54.0 markdown-3.4.3 tensorboard-2.0.0 werkzeug-2.2.3

# %%
import tensorboard
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# Traceback (most recent call last):
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\Scripts\tensorboard.exe\__main__.py", line 4, in <module>
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\main.py", line 40, in <module>
#     from tensorboard import default
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\default.py", line 38, in <module>
#     from tensorboard.plugins.audio import audio_plugin
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\plugins\audio\audio_plugin.py", line 25, in <module>
#     from tensorboard import plugin_util
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\plugin_util.py", line 21, in <module>
#     from tensorboard._vendor import bleach
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\_vendor\bleach\__init__.py", line 5, in <module>
#     from tensorboard._vendor.bleach.linkifier import (
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\_vendor\bleach\linkifier.py", line 4, in <module>
#     from tensorboard._vendor import html5lib
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\_vendor\html5lib\__init__.py", line 25, in <module>
#     from .html5parser import HTMLParser, parse, parseFragment
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\_vendor\html5lib\html5parser.py", line 8, in <module>
#     from . import _tokenizer
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\_vendor\html5lib\_tokenizer.py", line 16, in <module>
#     from ._trie import Trie
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\_vendor\html5lib\_trie\__init__.py", line 3, in <module>
#     from .py import Trie as PyTrie
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\_vendor\html5lib\_trie\py.py", line 6, in <module>
#     from ._base import Trie as ABCTrie
#   File "C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\tensorboard\_vendor\html5lib\_trie\_base.py", line 3, in <module>
#     from collections import Mapping
# ImportError: cannot import name 'Mapping' from 'collections' (C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\collections\__init__.py)

# %%
model_checkpoint = ModelCheckpoint(
    filename="{epoch}-{step}-{val_loss:.4f}", save_last=True, save_top_k=3, monitor="val_loss", mode="min"
)

trainer = pl.Trainer(
    accelerator="gpu", 
    precision=16,
    devices=1,
    max_epochs=1,
    callbacks=[
        model_checkpoint
    ],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 model_checkpoint = ModelCheckpoint(
#       2     filename="{epoch}-{step}-{val_loss:.4f}", save_last=True, save_top_k=3, monitor="val_loss", mode="min"
#       3 )
#       5 trainer = pl.Trainer(
#       6     accelerator="gpu",
#       7     precision=16,
#    (...)
#      12     ],
#      13 )
#
# NameError: name 'ModelCheckpoint' is not defined

# %%
trainer.fit(model_module, train_data_loader, test_data_loader)
# Out:
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name           | Type                                | Params
# -----------------------------------------------------------------------
# 0 | model          | LayoutLMv3ForSequenceClassification | 125 M
# 1 | train_accuracy | MulticlassAccuracy                  | 0
# 2 | val_accuracy   | MulticlassAccuracy                  | 0
# -----------------------------------------------------------------------
# 125 M     Trainable params
# 0         Non-trainable params
# 125 M     Total params
# 251.843   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.9/dist-packages/transformers/modeling_utils.py:830: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.

# %% [markdown]
# ## Evaluation

# %%
model_checkpoint.best_model_path
# Out:
# '/content/lightning_logs/version_0/checkpoints/epoch=3-step=1032-val_loss=0.1458.ckpt'

# %%
trained_model = ModelModule.load_from_checkpoint(
    model_checkpoint.best_model_path, 
    n_classes=len(DOCUMENT_CLASSES), 
    local_files_only=True
)
# Out:
# Some weights of LayoutLMv3ForSequenceClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trained_model.model.save_pretrained(Path("best-model"))

# %%
notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.huggingface/token
# Login successful

# %%
trained_model.model.push_to_hub("layoutlmv3-financial-document-classification")
# Out:
# CommitInfo(commit_url='https://huggingface.co/curiousily/layoutlmv3-financial-document-classification/commit/3f80ec262427f7b42f2ef4b905a0a91fe2a1b3bd', commit_message='Upload LayoutLMv3ForSequenceClassification', commit_description='', oid='3f80ec262427f7b42f2ef4b905a0a91fe2a1b3bd', pr_url=None, pr_revision=None, pr_num=None)

# %%
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
model = LayoutLMv3ForSequenceClassification.from_pretrained("curiousily/layoutlmv3-financial-document-classification")
model = model.eval().to(DEVICE)

# %%
def predict_document_image(
    image_path: Path, 
    model: LayoutLMv3ForSequenceClassification, 
    processor: LayoutLMv3Processor):

    json_path = image_path.with_suffix(".json")
    with json_path.open("r") as f:
        ocr_result = json.load(f)

        with Image.open(image_path).convert("RGB") as image:

            width, height = image.size
            width_scale = 1000 / width
            height_scale = 1000 / height
    
            words = []
            boxes = []
            for row in ocr_result:
                boxes.append(
                    scale_bounding_box(
                        row["bounding_box"], 
                        width_scale, 
                        height_scale
                    )
                )
                words.append(row["word"])
    
            encoding = processor(
                image, 
                words,
                boxes=boxes,
                max_length=512,
                padding="max_length",
                truncation=True,
                return_tensors="pt"
            )

    with torch.inference_mode():
        output = model(
            input_ids=encoding["input_ids"].to(DEVICE),
            attention_mask=encoding["attention_mask"].to(DEVICE),
            bbox=encoding["bbox"].to(DEVICE),
            pixel_values=encoding["pixel_values"].to(DEVICE)
        )

    predicted_class = output.logits.argmax()
    return model.config.id2label[predicted_class.item()]

# %%
labels = []
predictions = []
for image_path in tqdm(test_images):
    labels.append(image_path.parent.name)
    predictions.append(predict_document_image(image_path, model, processor))
# Out:
#   0%|          | 0/515 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/transformers/modeling_utils.py:768: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# 100%|██████████| 515/515 [00:50<00:00, 10.19it/s]

# %%
cm = confusion_matrix(labels, predictions, labels=DOCUMENT_CLASSES)
cm_display = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=DOCUMENT_CLASSES
)

cm_display.plot()
cm_display.ax_.set_xticklabels(DOCUMENT_CLASSES, rotation=45)
cm_display.figure_.set_size_inches(16, 8)

plt.show();
