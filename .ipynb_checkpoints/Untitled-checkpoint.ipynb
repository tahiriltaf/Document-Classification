5 MB 1.4 MB/s eta 0:00:06
#      --------------------------------- ------ 35.7/42.5 MB 1.4 MB/s eta 0:00:05
#      --------------------------------- ------ 35.8/42.5 MB 1.4 MB/s eta 0:00:05
#      --------------------------------- ------ 35.8/42.5 MB 1.4 MB/s eta 0:00:05
#      --------------------------------- ------ 35.9/42.5 MB 1.4 MB/s eta 0:00:05
#      --------------------------------- ------ 36.0/42.5 MB 1.4 MB/s eta 0:00:05
#      --------------------------------- ------ 36.0/42.5 MB 1.4 MB/s eta 0:00:05
#      --------------------------------- ------ 36.1/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.2/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.2/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.3/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.4/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.5/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.5/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.5/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.6/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.7/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.8/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.8/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.8/42.5 MB 1.3 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.9/42.5 MB 1.3 MB/s eta 0:00:05
#      ---------------------------------- ----- 36.9/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 37.0/42.5 MB 1.4 MB/s eta 0:00:05
#      ---------------------------------- ----- 37.1/42.5 MB 1.3 MB/s eta 0:00:05
#      ---------------------------------- ----- 37.1/42.5 MB 1.4 MB/s eta 0:00:04
#      ---------------------------------- ----- 37.2/42.5 MB 1.3 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.2/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.3/42.5 MB 1.3 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.4/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.4/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.5/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.6/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.6/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.7/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.7/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.8/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 37.9/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 38.0/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 38.0/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 38.1/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 38.2/42.5 MB 1.4 MB/s eta 0:00:04
#      ----------------------------------- ---- 38.2/42.5 MB 1.4 MB/s eta 0:00:04
#      ------------------------------------ --- 38.3/42.5 MB 1.4 MB/s eta 0:00:04
#      ------------------------------------ --- 38.4/42.5 MB 1.4 MB/s eta 0:00:04
#      ------------------------------------ --- 38.4/42.5 MB 1.3 MB/s eta 0:00:04
#      ------------------------------------ --- 38.5/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------ --- 38.5/42.5 MB 1.3 MB/s eta 0:00:03
#      ------------------------------------ --- 38.6/42.5 MB 1.3 MB/s eta 0:00:03
#      ------------------------------------ --- 38.7/42.5 MB 1.3 MB/s eta 0:00:03
#      ------------------------------------ --- 38.8/42.5 MB 1.3 MB/s eta 0:00:03
#      ------------------------------------ --- 38.8/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------ --- 38.9/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------ --- 39.0/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------ --- 39.1/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------ --- 39.1/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------ --- 39.1/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------ --- 39.3/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------- -- 39.3/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------- -- 39.4/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------- -- 39.4/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------- -- 39.5/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------- -- 39.6/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------- -- 39.6/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------- -- 39.7/42.5 MB 1.4 MB/s eta 0:00:03
#      ------------------------------------- -- 39.8/42.5 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------- -- 39.8/42.5 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------- -- 39.9/42.5 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------- -- 40.0/42.5 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------- -- 40.0/42.5 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------- -- 40.1/42.5 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------- -- 40.2/42.5 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------- -- 40.2/42.5 MB 1.4 MB/s eta 0:00:02
#      ------------------------------------- -- 40.3/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.4/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.4/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.5/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.5/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.6/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.7/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.7/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.8/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.8/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.9/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 40.9/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 41.0/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 41.1/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 41.1/42.5 MB 1.4 MB/s eta 0:00:02
#      -------------------------------------- - 41.2/42.5 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 41.2/42.5 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 41.3/42.5 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 41.3/42.5 MB 1.3 MB/s eta 0:00:01
#      -------------------------------------- - 41.4/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  41.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  41.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  41.6/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  41.7/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  41.7/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  41.8/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  41.8/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  41.9/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.0/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.0/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.1/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.2/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.2/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.3/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.4/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  42.5/42.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 42.5/42.5 MB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages (from scikit-learn) (1.23.5)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ---------------------------------------- 0.0/298.0 kB ? eta -:--:--
#      ---------- ---------------------------- 81.9/298.0 kB 2.3 MB/s eta 0:00:01
#      ------------------ ------------------- 143.4/298.0 kB 2.1 MB/s eta 0:00:01
#      ---------------------------- --------- 225.3/298.0 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------  297.0/298.0 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 298.0/298.0 kB 1.5 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.2 scipy-1.10.1 threadpoolctl-3.1.0

# %%
# !pip install Pillow
# !pip install pytesseract
# Out:
# Requirement already satisfied: Pillow in c:\users\tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages (9.4.0)
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages (from pytesseract) (23.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages (from pytesseract) (9.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10

# %%
import os
dataset_path = "./Data/Document Classification"
labels = [label for label in os.listdir(dataset_path)]
idx2label = {v: k for v, k in enumerate(labels)}
label2idx = {k: v for v, k in enumerate(labels)}
label2idx
# Out:
# {'email': 0, 'resume': 1, 'scientific_publication': 2}

# %%
from datasets import load_dataset 

# this dataset uses the new Image feature :)
dataset = load_dataset(dataset_path)
# Out:
# Resolving data files:   0%|          | 0/165 [00:00<?, ?it/s]
# Found cached dataset imagefolder (C:/Users/Tahir iltaf/.cache/huggingface/datasets/imagefolder/Document Classification-0d21771c2e5ecfca/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 165
#     })
# })

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
images = []
labels = []

for label in os.listdir(dataset_path):
    images.extend([
        f"{dataset_path}/{label}/{img_name}" for img_name in os.listdir(f"{dataset_path}/{label}")
    ])
    labels.extend([
        label for _ in range(len(os.listdir(f"{dataset_path}/{label}")))
    ])
data = pd.DataFrame({'image_path': images, 'label': labels})

train_data, valid_data = train_test_split(data, test_size=0.09, random_state=0, stratify=data.label)
train_data = train_data.reset_index(drop=True)
valid_data = valid_data.reset_index(drop=True)
print(f"{len(train_data)} training examples, {len(valid_data)} validation examples")
data.head()
# Out:
# 150 training examples, 15 validation examples
#                                           image_path  label
# 0  ./Data/Document Classification/email/doc_00004...  email
# 1  ./Data/Document Classification/email/doc_00004...  email
# 2  ./Data/Document Classification/email/doc_00007...  email
# 3  ./Data/Document Classification/email/doc_00007...  email
# 4  ./Data/Document Classification/email/doc_00011...  email

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from datasets import Dataset, Features, Sequence, ClassLabel, Value, Array2D, Array3D
def encode_training_example(examples):
    images = [Image.open(path).convert("RGB") for path in examples['image_path']]
    encoded_inputs = processor(images, padding="max_length", truncation=True)
    encoded_inputs["labels"] = [label2idx[label] for label in examples["label"]]
    
    return encoded_inputs

training_features = Features({
    'image': Array3D(dtype="int64", shape=(3, 224, 224)),
    'input_ids': Sequence(feature=Value(dtype='int64')),
    'attention_mask': Sequence(Value(dtype='int64')),
    'token_type_ids': Sequence(Value(dtype='int64')),
    'bbox': Array2D(dtype="int64", shape=(512, 4)),
    'labels': ClassLabel(num_classes=len(label2idx), names=list(label2idx.keys())),
})

# %%
from datasets import Dataset, Features, Sequence, ClassLabel, Value, Array2D, Array3D
def encode_training_example(examples):
    images = [Image.open(path).convert("RGB") for path in examples['image_path']]
    encoded_inputs = processor(images, padding="max_length", truncation=True)
    encoded_inputs["labels"] = [label2idx[label] for label in examples["label"]]
    
    return encoded_inputs

training_features = Features({
    'pixel_values': Array3D(dtype="float16", shape=(3, 224, 224)),
    'input_ids': Sequence(feature=Value(dtype='int64')),
    'attention_mask': Sequence(Value(dtype='int64')),
    'token_type_ids': Sequence(Value(dtype='int64')),
    'bbox': Array2D(dtype="int64", shape=(512, 4)),
    'labels': ClassLabel(num_classes=len(label2idx), names=list(label2idx.keys())),
})

# %%
def training_dataloader_from_df(data):
    dataset = Dataset.from_pandas(data)
    
    encoded_dataset = dataset.map(
        encode_training_example, remove_columns=dataset.column_names, features=training_features, 
        batched=True, batch_size=2
    )
    encoded_dataset.set_format(type='torch', device=device)
    dataloader = torch.utils.data.DataLoader(encoded_dataset, batch_size=4, shuffle=True)
    batch = next(iter(dataloader))
    return dataloader

# %%
from transformers import LayoutLMv2FeatureExtractor, LayoutLMv2Tokenizer, LayoutLMv2Processor, LayoutLMv2ForSequenceClassification
from PIL import Image
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
import pytesseract

feature_extractor = LayoutLMv2FeatureExtractor()
tokenizer = LayoutLMv2Tokenizer.from_pretrained("microsoft/layoutlmv2-base-uncased")
processor = LayoutLMv2Processor(feature_extractor, tokenizer)

train_dataloader = training_dataloader_from_df(train_data)
valid_dataloader = training_dataloader_from_df(valid_data)
# Out:
# Map:   0%|          | 0/150 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 10
#       7 tokenizer = LayoutLMv2Tokenizer.from_pretrained("microsoft/layoutlmv2-base-uncased")
#       8 processor = LayoutLMv2Processor(feature_extractor, tokenizer)
# ---> 10 train_dataloader = training_dataloader_from_df(train_data)
#      11 valid_dataloader = training_dataloader_from_df(valid_data)
#
# Cell In[19], line 4, in training_dataloader_from_df(data)
#       1 def training_dataloader_from_df(data):
#       2     dataset = Dataset.from_pandas(data)
# ----> 4     encoded_dataset = dataset.map(
#       5         encode_training_example, remove_columns=dataset.column_names, features=training_features,
#       6         batched=True, batch_size=2
#       7     )
#       8     encoded_dataset.set_format(type='torch', device=device)
#       9     dataloader = torch.utils.data.DataLoader(encoded_dataset, batch_size=4, shuffle=True)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:563, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     561     self: "Dataset" = kwargs.pop("self")
#     562 # apply actual function
# --> 563 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     564 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     565 for dataset in datasets:
#     566     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:528, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     521 self_format = {
#     522     "type": self._format_type,
#     523     "format_kwargs": self._format_kwargs,
#     524     "columns": self._format_columns,
#     525     "output_all_columns": self._output_all_columns,
#     526 }
#     527 # apply actual function
# --> 528 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     529 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     530 # re-apply format to the output
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:3004, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    2996 if transformed_dataset is None:
#    2997     with logging.tqdm(
#    2998         disable=not logging.is_progress_bar_enabled(),
#    2999         unit=" examples",
#    (...)
#    3002         desc=desc or "Map",
#    3003     ) as pbar:
# -> 3004         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3005             if done:
#    3006                 shards_done += 1
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:3397, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3395         writer.write_table(batch)
#    3396     else:
# -> 3397         writer.write_batch(batch)
#    3398 num_examples_progress_update += num_examples_in_batch
#    3399 if time.time() > _time + config.PBAR_REFRESH_TIME_INTERVAL:
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_writer.py:543, in ArrowWriter.write_batch(self, batch_examples, writer_batch_size)
#     541 for col in cols:
#     542     col_values = batch_examples[col]
# --> 543     col_type = features[col] if features else None
#     544     if isinstance(col_values, (pa.Array, pa.ChunkedArray)):
#     545         array = cast_array_to_feature(col_values, col_type) if col_type is not None else col_values
#
# KeyError: 'image'

# %%
from transformers import LayoutLMv3FeatureExtractor, LayoutLMv3TokenizerFast, LayoutLMv3Processor, LayoutLMv3ForSequenceClassification
from PIL import Image
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
import pytesseract

# feature_extractor = LayoutLMv3FeatureExtractor(apply_ocr=False)
# tokenizer = LayoutLMv3TokenizerFast.from_pretrained(
#     "microsoft/layoutlmv3-base"
# )
# processor = LayoutLMv3Processor(feature_extractor, tokenizer)

feature_extractor = LayoutLMv3FeatureExtractor()
tokenizer = LayoutLMv3TokenizerFast.from_pretrained( "microsoft/layoutlmv3-base")
processor = LayoutLMv3Processor(feature_extractor, tokenizer)

train_dataloader = training_dataloader_from_df(train_data)
valid_dataloader = training_dataloader_from_df(valid_data)
# Out:
# Map:   0%|          | 0/150 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:3397, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3396     else:
# -> 3397         writer.write_batch(batch)
#    3398 num_examples_progress_update += num_examples_in_batch
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_writer.py:538, in ArrowWriter.write_batch(self, batch_examples, writer_batch_size)
#     534 inferred_features = Features()
#     535 cols = (
#     536     [col for col in self.schema.names if col in batch_examples]
#     537     + [col for col in batch_examples.keys() if col not in self.schema.names]
# --> 538     if self.schema
#     539     else batch_examples.keys()
#     540 )
#     541 for col in cols:
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_writer.py:405, in ArrowWriter.schema(self)
#     400 @property
#     401 def schema(self):
#     402     _schema = (
#     403         self._schema
#     404         if self._schema is not None
# --> 405         else (pa.schema(self._features.type) if self._features is not None else None)
#     406     )
#     407     if self._disable_nullable and _schema is not None:
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:1591, in Features.type(self)
#    1585 """
#    1586 Features field types.
#    1587
#    1588 Returns:
#    1589     :obj:`pyarrow.DataType`
#    1590 """
# -> 1591 return get_nested_type(self)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:1178, in get_nested_type(schema)
#    1176 if isinstance(schema, Features):
#    1177     return pa.struct(
# -> 1178         {key: get_nested_type(schema[key]) for key in schema}
#    1179     )  # Features is subclass of dict, and dict order is deterministic since Python 3.6
#    1180 elif isinstance(schema, dict):
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:1178, in <dictcomp>(.0)
#    1176 if isinstance(schema, Features):
#    1177     return pa.struct(
# -> 1178         {key: get_nested_type(schema[key]) for key in schema}
#    1179     )  # Features is subclass of dict, and dict order is deterministic since Python 3.6
#    1180 elif isinstance(schema, dict):
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:1197, in get_nested_type(schema)
#    1196 # Other objects are callable which returns their data type (ClassLabel, Array2D, Translation, Arrow datatype creation methods)
# -> 1197 return schema()
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:520, in _ArrayXD.__call__(self)
#     519 def __call__(self):
# --> 520     pa_type = globals()[self.__class__.__name__ + "ExtensionType"](self.shape, self.dtype)
#     521     return pa_type
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:639, in _ArrayXDExtensionType.__init__(self, shape, dtype)
#     638 self.value_type = dtype
# --> 639 self.storage_dtype = self._generate_dtype(self.value_type)
#     640 pa.PyExtensionType.__init__(self, self.storage_dtype)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:655, in _ArrayXDExtensionType._generate_dtype(self, dtype)
#     654 def _generate_dtype(self, dtype):
# --> 655     dtype = string_to_arrow(dtype)
#     656     for d in reversed(self.shape):
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:256, in string_to_arrow(datasets_dtype)
#     244         raise ValueError(
#     245             _dtype_error_msg(
#     246                 datasets_dtype,
#    (...)
#     253             )
#     254         )
# --> 256 raise ValueError(
#     257     f"Neither {datasets_dtype} nor {datasets_dtype + '_'} seems to be a pyarrow data type. "
#     258     f"Please make sure to use a correct data type, see: "
#     259     f"https://arrow.apache.org/docs/python/api/datatypes.html#factory-functions"
#     260 )
#
# ValueError: Neither float nor float_ seems to be a pyarrow data type. Please make sure to use a correct data type, see: https://arrow.apache.org/docs/python/api/datatypes.html#factory-functions
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 16
#      13 tokenizer = LayoutLMv3TokenizerFast.from_pretrained( "microsoft/layoutlmv3-base")
#      14 processor = LayoutLMv3Processor(feature_extractor, tokenizer)
# ---> 16 train_dataloader = training_dataloader_from_df(train_data)
#      17 valid_dataloader = training_dataloader_from_df(valid_data)
#
# Cell In[24], line 4, in training_dataloader_from_df(data)
#       1 def training_dataloader_from_df(data):
#       2     dataset = Dataset.from_pandas(data)
# ----> 4     encoded_dataset = dataset.map(
#       5         encode_training_example, remove_columns=dataset.column_names, features=training_features,
#       6         batched=True, batch_size=2
#       7     )
#       8     encoded_dataset.set_format(type='torch', device=device)
#       9     dataloader = torch.utils.data.DataLoader(encoded_dataset, batch_size=4, shuffle=True)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:563, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     561     self: "Dataset" = kwargs.pop("self")
#     562 # apply actual function
# --> 563 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     564 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     565 for dataset in datasets:
#     566     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:528, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     521 self_format = {
#     522     "type": self._format_type,
#     523     "format_kwargs": self._format_kwargs,
#     524     "columns": self._format_columns,
#     525     "output_all_columns": self._output_all_columns,
#     526 }
#     527 # apply actual function
# --> 528 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     529 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     530 # re-apply format to the output
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:3004, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    2996 if transformed_dataset is None:
#    2997     with logging.tqdm(
#    2998         disable=not logging.is_progress_bar_enabled(),
#    2999         unit=" examples",
#    (...)
#    3002         desc=desc or "Map",
#    3003     ) as pbar:
# -> 3004         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3005             if done:
#    3006                 shards_done += 1
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_dataset.py:3409, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3407 if update_data:
#    3408     if writer is not None:
# -> 3409         writer.finalize()
#    3410     if tmp_file is not None:
#    3411         tmp_file.close()
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_writer.py:584, in ArrowWriter.finalize(self, close_stream)
#     582 self.write_examples_on_file()
#     583 # If schema is known, infer features even if no examples were written
# --> 584 if self.pa_writer is None and self.schema:
#     585     self._build_writer(self.schema)
#     586 if self.pa_writer is not None:
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\arrow_writer.py:405, in ArrowWriter.schema(self)
#     400 @property
#     401 def schema(self):
#     402     _schema = (
#     403         self._schema
#     404         if self._schema is not None
# --> 405         else (pa.schema(self._features.type) if self._features is not None else None)
#     406     )
#     407     if self._disable_nullable and _schema is not None:
#     408         _schema = pa.schema(pa.field(field.name, field.type, nullable=False) for field in _schema)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:1591, in Features.type(self)
#    1583 @property
#    1584 def type(self):
#    1585     """
#    1586     Features field types.
#    1587
#    1588     Returns:
#    1589         :obj:`pyarrow.DataType`
#    1590     """
# -> 1591     return get_nested_type(self)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:1178, in get_nested_type(schema)
#    1175 # Nested structures: we allow dict, list/tuples, sequences
#    1176 if isinstance(schema, Features):
#    1177     return pa.struct(
# -> 1178         {key: get_nested_type(schema[key]) for key in schema}
#    1179     )  # Features is subclass of dict, and dict order is deterministic since Python 3.6
#    1180 elif isinstance(schema, dict):
#    1181     return pa.struct(
#    1182         {key: get_nested_type(schema[key]) for key in schema}
#    1183     )  # however don't sort on struct types since the order matters
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:1178, in <dictcomp>(.0)
#    1175 # Nested structures: we allow dict, list/tuples, sequences
#    1176 if isinstance(schema, Features):
#    1177     return pa.struct(
# -> 1178         {key: get_nested_type(schema[key]) for key in schema}
#    1179     )  # Features is subclass of dict, and dict order is deterministic since Python 3.6
#    1180 elif isinstance(schema, dict):
#    1181     return pa.struct(
#    1182         {key: get_nested_type(schema[key]) for key in schema}
#    1183     )  # however don't sort on struct types since the order matters
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:1197, in get_nested_type(schema)
#    1194     return pa.list_(value_type, schema.length)
#    1196 # Other objects are callable which returns their data type (ClassLabel, Array2D, Translation, Arrow datatype creation methods)
# -> 1197 return schema()
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:520, in _ArrayXD.__call__(self)
#     519 def __call__(self):
# --> 520     pa_type = globals()[self.__class__.__name__ + "ExtensionType"](self.shape, self.dtype)
#     521     return pa_type
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:639, in _ArrayXDExtensionType.__init__(self, shape, dtype)
#     637 self.shape = tuple(shape)
#     638 self.value_type = dtype
# --> 639 self.storage_dtype = self._generate_dtype(self.value_type)
#     640 pa.PyExtensionType.__init__(self, self.storage_dtype)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:655, in _ArrayXDExtensionType._generate_dtype(self, dtype)
#     654 def _generate_dtype(self, dtype):
# --> 655     dtype = string_to_arrow(dtype)
#     656     for d in reversed(self.shape):
#     657         dtype = pa.list_(dtype)
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\datasets\features\features.py:256, in string_to_arrow(datasets_dtype)
#     243     else:
#     244         raise ValueError(
#     245             _dtype_error_msg(
#     246                 datasets_dtype,
#    (...)
#     253             )
#     254         )
# --> 256 raise ValueError(
#     257     f"Neither {datasets_dtype} nor {datasets_dtype + '_'} seems to be a pyarrow data type. "
#     258     f"Please make sure to use a correct data type, see: "
#     259     f"https://arrow.apache.org/docs/python/api/datatypes.html#factory-functions"
#     260 )
#
# ValueError: Neither float nor float_ seems to be a pyarrow data type. Please make sure to use a correct data type, see: https://arrow.apache.org/docs/python/api/datatypes.html#factory-functions

# %%
# !pip show pytesseract
# Out:
# Name: pytesseract
# Version: 0.3.10
# Summary: Python-tesseract is a python wrapper for Google's Tesseract-OCR
# Home-page: https://github.com/madmaze/pytesseract
# Author: Samuel Hoffstaetter
# Author-email: samuel@hoffstaetter.com
# License: Apache License 2.0
# Location: c:\users\tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages
# Requires: packaging, Pillow
# Required-by:

# %%
# model = LayoutLMv2ForSequenceClassification.from_pretrained(
#     "microsoft/layoutlmv2-base-uncased",  num_labels=len(label2idx)
# )
# model.to(device);

# %%
from transformers import LayoutLMv3FeatureExtractor, LayoutLMv3TokenizerFast, LayoutLMv3Processor, LayoutLMv3ForSequenceClassification

model = LayoutLMv3ForSequenceClassification.from_pretrained(
    "microsoft/layoutlmv3-base",  num_labels=len(label2idx))
model.to(device);
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/856 [00:00<?, ?B/s]
# C:\Users\Tahir iltaf\.conda\envs\layoutlmv3_env\lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Tahir iltaf\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of LayoutLMv3ForSequenceClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import AdamW
from tqdm.auto import tqdm
optimizer = AdamW(model.parameters(), lr=5e-5)
num_epochs = 1


for epoch in range(num_epochs):
    print("Epoch:", epoch)
    training_loss = 0.0
    training_correct = 0
    #put the model in training mode
    model.train()
    for batch in tqdm(train_dataloader):
        outputs = model(**batch)
        loss = outputs.loss

        training_loss += loss.item()
        predictions = outputs.logits.argmax(-1)
        training_correct += (predictions == batch['labels']).float().sum()

        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    print("Training Loss:", training_loss / batch["input_ids"].shape[0])
    training_accuracy = 100 * training_correct / len(train_data)
    print("Training accuracy:", training_accuracy.item())  
        
    validation_loss = 0.0
    validation_correct = 0
    for batch in tqdm(valid_dataloader):
        outputs = model(**batch)
        loss = outputs.loss

        validation_loss += loss.item()
        predictions = outputs.logits.argmax(-1)
        validation_correct += (predictions == batch['labels']).float().sum()

    print("Validation Loss:", validation_loss / batch["input_ids"].shape[0])
    validation_accuracy = 100 * validation_correct / len(valid_data)
    print("Validation accuracy:", validation_accuracy.item())
# Out:
# Epoch: 0
#   0%|          | 0/38 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 14
#      12 model.train()
#      13 for batch in tqdm(train_dataloader):
# ---> 14     outputs = model(**batch)
#      15     loss = outputs.loss
#      17     training_loss += loss.item()
#
# File ~\.conda\envs\layoutlmv3_env\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: LayoutLMv3ForSequenceClassification.forward() got an unexpected keyword argument 'image'
